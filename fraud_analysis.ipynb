# %%
import pandas as pd 
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01_data_cleaning_eda.ipynb',
#  'creditcard.csv',
#  'My Music',
#  'My Pictures',
#  'My Videos']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Class', data=df)
plt.title("Fraud vs Normal Transactions")
plt.show()

# %%
sns.histplot(df['Amount'], bins=50)
plt.title("Transaction Amount Distribution")
plt.show()

# %%
sns.boxplot(x='Class', y='Amount', data=df)
plt.title("Fraud vs Normal Transaction Amount")
plt.show()

# %%
df['Hour'] = (df['Time'] // 3600) % 24
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.countplot(x='Hour', data=df)
plt.title("Transactions by Hour")
plt.xticks(rotation=90)
plt.show()

# %%
fraud_data = df[df['Class'] == 1]

plt.figure(figsize=(10,5))
sns.countplot(x='Hour', data=fraud_data)
plt.title("Fraud Transactions by Hour")
plt.xticks(rotation=90)
plt.show()

# %%
import numpy as np

df['Log_Amount'] = np.log1p(df['Amount'])

sns.boxplot(x='Class', y='Log_Amount', data=df)
plt.title("Fraud vs Normal (Log Amount)")
plt.show()

# %%
df.sort_values(by='Amount', ascending=False).head(10)
# Out:
#             Time         V1         V2         V3         V4          V5  \
# 274771  166198.0 -35.548539 -31.850484 -48.325589  15.304184 -113.743307
# 58465    48401.0 -36.802320 -63.344698 -20.645794  16.715537  -20.672064
# 151296   95286.0 -34.549296 -60.464618 -21.340854  16.875344  -19.229075
# 46841    42951.0 -23.712839 -42.172688 -13.320825   9.925019  -13.945538
# 54018    46253.0 -21.780665 -38.305310 -12.122469   9.752791  -12.880794
# 169457  119713.0 -20.924897 -37.943452 -14.060281  10.473005  -10.866639
# 284249  172273.0  -9.030538 -11.112584 -16.233798   3.592021  -40.427726
# 227921  145283.0 -21.532478 -34.704768  -8.303035  10.264175    3.957175
# 74699    55709.0 -16.950064 -16.417395 -12.523381   6.555638  -27.752964
# 245474  152763.0 -14.641710 -28.554825 -12.714462   5.878264   -7.855074
#
#                V6          V7         V8        V9  ...        V23       V24  \
# 274771  73.301626  120.589494 -27.347360 -3.872425  ...  -1.581098  4.584549
# ...

# %%
fraud = df[df['Class'] == 1]
fraud.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V23       V24       V25  \
# 541  -2.537387  1.391657 -2.770089  ... -0.465211  0.320198  0.044519
# 623   0.325574 -0.067794 -0.270953  ...  1.375966 -0.293803  0.279798
# 4920  0.562320 -0.399147 -0.238253  ...  0.172726 -0.087330 -0.156114
# 6108 -3.496197 -0.248778 -0.247768  ... -0.436207 -0.053502  0.252405
# 6329  1.713445 -0.496358 -1.282858  ... -0.656805 -1.632653  1.488901
#
#            V26       V27       V28  Amount  Class  Hour  Log_Amount
# ...

# %%
df.groupby('Class')['Amount'].mean()
# Out:
# Class
# 0     88.291022
# 1    122.211321
# Name: Amount, dtype: float64

# %%
df['Class'].value_counts(normalize=True) * 100
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
df.groupby('Hour')['Class'].sum().sort_values(ascending=False)
# Out:
# Hour
# 2.0     57
# 11.0    53
# 18.0    33
# 17.0    29
# 15.0    26
# 4.0     23
# 7.0     23
# 14.0    23
# 16.0    22
# 23.0    21
# 19.0    19
# 20.0    18
# 13.0    17
# 12.0    17
# 3.0     17
# 9.0     16
# 21.0    16
# 5.0     11
# 1.0     10
# 8.0      9
# 6.0      9
# 22.0     9
# 10.0     8
# 0.0      6
# Name: Class, dtype: int64

# %% [markdown]
# FINAL INSIGHTS:
#
# 1. Fraud transactions are very rare compared to normal transactions.
# 2. Fraud is not dependent only on transaction amount.
# 3. Certain time periods show higher fraud activity.
# 4. Behavioral patterns are more important than raw values.

# %% [markdown]
# BUSINESS RECOMMENDATIONS:
#
# 1. Monitor high-risk time periods.
# 2. Use behavior-based fraud detection instead of only amount.
# 3. Implement real-time alert system for suspicious transactions.

# %% [markdown]
# This project helps financial institutions identify fraud patterns using data analysis techniques.

# %% [markdown]
# # Financial Transaction Risk Analysis & Fraud Detection
